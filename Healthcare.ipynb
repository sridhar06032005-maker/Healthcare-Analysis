# %%
Dataset questions

#How many rows and columns are present in the dataset?

#Display first 10 records.

#Show all column names.

#Check datatype of each column.

#Count total number of patients.

#Find unique medical conditions available.

#Find unique hospitals in the dataset.

#Count number of male and female patients.

#Show number of patients for each blood group.

#Find minimum and maximum age of patients.

2️⃣ Filtering Queries

#Show all patients who are Female.

#Display patients whose Age > 60.

#Show patients with Diabetes.

#Find patients admitted under Emergency admission type.

#Show patients whose Test Results = Abnormal.

#Display patients whose Blood Type = O+.

#Show patients treated in a particular hospital (example: White-White).

#Find patients who took Ibuprofen medication.

# %%
import pandas as pd
df = pd.read_csv("d:/healthcare_dataset.csv")
df.head(10)
# Out:
#                  Name  Age  Gender Blood Type Medical Condition  \
# 0       Bobby JacksOn   30    Male         B-            Cancer
# 1        LesLie TErRy   62    Male         A+           Obesity
# 2         DaNnY sMitH   76  Female         A-           Obesity
# 3        andrEw waTtS   28  Female         O+          Diabetes
# 4       adrIENNE bEll   43  Female        AB+            Cancer
# 5       EMILY JOHNSOn   36    Male         A+            Asthma
# 6      edwArD EDWaRDs   21  Female        AB-          Diabetes
# 7  CHrisTInA MARtinez   20  Female         A+            Cancer
# 8     JASmINe aGuIlaR   82    Male        AB+            Asthma
# 9    ChRISTopher BerG   58  Female        AB-            Cancer
#
#   Date of Admission            Doctor                     Hospital  \
# 0        2024-01-31     Matthew Smith              Sons and Miller
# 1        2019-08-20   Samantha Davies                      Kim Inc
# ...

# %%
columns_to_fix = ['Name', 'Gender', 'Doctor', 'Hospital', 
                  'Insurance Provider', 'Medical Condition', 'Medication']

for col in columns_to_fix:
    df[col] = df[col].str.strip().str.title()

# check
print(df.head())
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby Jackson   30    Male         B-            Cancer        2024-01-31
# 1   Leslie Terry   62    Male         A+           Obesity        2019-08-20
# 2    Danny Smith   76  Female         A-           Obesity        2022-09-22
# 3   Andrew Watts   28  Female         O+          Diabetes        2020-11-18
# 4  Adrienne Bell   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons And Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook Plc              Aetna
# 3       Kevin Wells  Hernandez Rogers And Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
print("Shape of dataset:", df.shape)
# Out:
# Shape of dataset: (55500, 15)

# %%
df.head(10)
# Out:
#                  Name  Age  Gender Blood Type Medical Condition  \
# 0       Bobby Jackson   30    Male         B-            Cancer
# 1        Leslie Terry   62    Male         A+           Obesity
# 2         Danny Smith   76  Female         A-           Obesity
# 3        Andrew Watts   28  Female         O+          Diabetes
# 4       Adrienne Bell   43  Female        AB+            Cancer
# 5       Emily Johnson   36    Male         A+            Asthma
# 6      Edward Edwards   21  Female        AB-          Diabetes
# 7  Christina Martinez   20  Female         A+            Cancer
# 8     Jasmine Aguilar   82    Male        AB+            Asthma
# 9    Christopher Berg   58  Female        AB-            Cancer
#
#   Date of Admission            Doctor                     Hospital  \
# 0        2024-01-31     Matthew Smith              Sons And Miller
# 1        2019-08-20   Samantha Davies                      Kim Inc
# ...

# %%
df.tail()
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 55495  Elizabeth Jackson   42  Female         O+            Asthma
# 55496         Kyle Perez   61  Female        AB-           Obesity
# 55497       Heather Wang   38  Female         B+      Hypertension
# 55498     Jennifer Jones   43    Male         O-         Arthritis
# 55499       James Garcia   53  Female         O+         Arthritis
#
#       Date of Admission           Doctor                      Hospital  \
# 55495        2020-08-16    Joshua Jarvis                Jones-Thompson
# 55496        2020-01-23  Taylor Sullivan                  Tucker-Moyer
# 55497        2020-07-13   Joe Jacobs Dvm  And Mahoney Johnson Vasquez,
# 55498        2019-05-25   Kimberly Curry      Jackson Todd And Castro,
# 55499        2024-04-02    Dennis Warren                Henry Sons And
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# ...

# %%
df.describe()
# Out:
#                 Age  Billing Amount   Room Number
# count  55500.000000    55500.000000  55500.000000
# mean      51.539459    25539.316097    301.134829
# std       19.602454    14211.454431    115.243069
# min       13.000000    -2008.492140    101.000000
# 25%       35.000000    13241.224652    202.000000
# 50%       52.000000    25538.069376    302.000000
# 75%       68.000000    37820.508436    401.000000
# max       89.000000    52764.276736    500.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                55500 non-null  object
#  1   Age                 55500 non-null  int64
#  2   Gender              55500 non-null  object
#  3   Blood Type          55500 non-null  object
#  4   Medical Condition   55500 non-null  object
#  5   Date of Admission   55500 non-null  object
#  6   Doctor              55500 non-null  object
#  7   Hospital            55500 non-null  object
#  8   Insurance Provider  55500 non-null  object
#  9   Billing Amount      55500 non-null  float64
#  10  Room Number         55500 non-null  int64
#  11  Admission Type      55500 non-null  object
#  12  Discharge Date      55500 non-null  object
#  13  Medication          55500 non-null  object
#  14  Test Results        55500 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
type = df['Blood Type']
print(type)
print('\n')
type = df['Admission Type']
print(type)
# Out:
# 0         B-
# 1         A+
# 2         A-
# 3         O+
# 4        AB+
#         ...
# 55495     O+
# 55496    AB-
# 55497     B+
# 55498     O-
# 55499     O+
# Name: Blood Type, Length: 55500, dtype: object
#
#
# 0           Urgent
# 1        Emergency
# 2        Emergency
# 3         Elective
# 4           Urgent
#            ...
# 55495     Elective
# 55496     Elective
# 55497       Urgent
# 55498     Elective
# 55499       Urgent
# Name: Admission Type, Length: 55500, dtype: object

# %%
name = df['Name']
print(name)
print('\n')
age = df['Age']
print(age)
# Out:
# 0            Bobby Jackson
# 1             Leslie Terry
# 2              Danny Smith
# 3             Andrew Watts
# 4            Adrienne Bell
#                ...
# 55495    Elizabeth Jackson
# 55496           Kyle Perez
# 55497         Heather Wang
# 55498       Jennifer Jones
# 55499         James Garcia
# Name: Name, Length: 55500, dtype: object
#
#
# 0        30
# 1        62
# 2        76
# 3        28
# 4        43
#          ..
# 55495    42
# 55496    61
# 55497    38
# 55498    43
# 55499    53
# Name: Age, Length: 55500, dtype: int64

# %%
df.loc[13]
# Out:
# Name                      Robert Bauer
# Age                                 68
# Gender                          Female
# Blood Type                         AB+
# Medical Condition               Asthma
# Date of Admission           2020-05-22
# Doctor                 Theresa Freeman
# Hospital              Rivera-Gutierrez
# Insurance Provider    Unitedhealthcare
# Billing Amount            33207.706634
# Room Number                        309
# Admission Type                  Urgent
# Discharge Date              2020-06-19
# Medication                     Lipitor
# Test Results                    Normal
# Name: 13, dtype: object

# %%
print('Total Number Of Patients',df['Name'].count())
# Out:
# Total Number Of Patients 55500

# %%
df['Medical Condition'].unique()
# Out:
# array(['Cancer', 'Obesity', 'Diabetes', 'Asthma', 'Hypertension',
#        'Arthritis'], dtype=object)

# %%
df['Hospital'].unique()
# Out:
# array(['Sons And Miller', 'Kim Inc', 'Cook Plc', ...,
#        'Guzman Jones And Graves,', 'And Williams, Brown Mckenzie',
#        'Moreno Murphy, Griffith And'], shape=(39876,), dtype=object)

# %%
df.to_csv("d:/cleaned data healthcare.csv",index=False)

# %%
import mysql.connector
import pandas as pd
cn=mysql.connector.connect(host="127.0.0.1",user="root",password="SrIdHaR",database="healthcare")
q="SELECT * FROM healthcare"
df=pd.read_sql(q,cn) 
print(df)
# Out:
# C:\Users\srith\AppData\Local\Temp\ipykernel_2708\2616123792.py:5: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df=pd.read_sql(q,cn)
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby Jackson   30    Male         B-            Cancer
# 1           Leslie Terry   62    Male         A+           Obesity
# 2            Danny Smith   76  Female         A-           Obesity
# 3           Andrew Watts   28  Female         O+          Diabetes
# 4          Adrienne Bell   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  Elizabeth Jackson   42  Female         O+            Asthma
# 55496         Kyle Perez   61  Female        AB-           Obesity
# 55497       Heather Wang   38  Female         B+      Hypertension
# ...
